# %%
# Importing the required libraries

import numpy as np # Linear Algebra
import pandas as pd # Data Manipulation
import pickle
import warnings
warnings.filterwarnings('ignore')# Avoid warnings

# %%
# Importing the data

df = pd.read_csv("open_pubs.csv")

# %%
# Viewing the data

df.head()
# Out:
#    22          Anchor Inn        Upper Street, Stratford St Mary, COLCHESTER  \
# 0  36  Ark Bar Restaurant  Ark Bar And Restaurant, Cattawade Street, Bran...
# 1  74           Black Boy  The Lady Elizabeth, 7 Market Hill, SUDBURY, Su...
# 2  75         Black Horse        Lower Street, Stratford St Mary, COLCHESTER
# 3  76          Black Lion                      Lion Road, Glemsford, SUDBURY
# 4  97        Brewers Arms  The Brewers Arms, Bower House Tye, Polstead, C...
#
#     CO7 6LW  604749   234404  51.970379  0.979340  Babergh
# 0  CO11 1RH  610194   233329  51.958698  1.057832  Babergh
# 1  CO10 2EA  587334   241316  52.038595  0.729915  Babergh
# 2   CO7 6JS  622675 -5527598         \N        \N  Babergh
# 3  CO10 7RF  622675 -5527598         \N        \N  Babergh
# 4   CO6 5BZ  598743   240655  52.028694  0.895650  Babergh

# %%
df.columns =['fsa_id','name','address','postalcode','easting','northing','latitude','longitude','local_authority']
df
# Out:
#        fsa_id                                      name  \
# 0          36                        Ark Bar Restaurant
# 1          74                                 Black Boy
# 2          75                               Black Horse
# 3          76                                Black Lion
# 4          97                              Brewers Arms
# ...       ...                                       ...
# 51325  597119  Wrexham & District War Memorial Club Ltd
# 51326  597127                 Wrexham Lager Social Club
# 51327  597130         Wrexham Rail Sports & Social Club
# 51328  597131                        Wrexham Rugby Club
# 51329  597137                                     Y Tai
#
#                                                  address postalcode  easting  \
# 0      Ark Bar And Restaurant, Cattawade Street, Bran...   CO11 1RH   610194
# 1      The Lady Elizabeth, 7 Market Hill, SUDBURY, Su...   CO10 2EA   587334
# ...

# %%
df.describe()
# Out:
#               fsa_id        easting      northing
# count   51330.000000   51330.000000  5.133000e+04
# mean   299401.204189  429853.990610  2.271940e+05
# std    169358.946123   98556.969786  7.277459e+05
# min        36.000000   78110.000000 -5.527598e+06
# 25%    167800.500000  361449.000000  1.792435e+05
# 50%    303719.500000  428770.000000  2.872515e+05
# 75%    438957.750000  509795.750000  4.089420e+05
# max    597137.000000  655277.000000  1.209661e+06

# %%
a = df.isnull().any()

print(a)
# Out:
# fsa_id             False
# name               False
# address            False
# postalcode         False
# easting            False
# northing           False
# latitude           False
# longitude          False
# local_authority    False
# dtype: bool

# %%
# Numerical Columns

num_data = df.select_dtypes(['int64','float64'])

num_cols = num_data.columns

print('Numerical Columns : {}'.format(list(num_cols)))
# Out:
# Numerical Columns : ['fsa_id', 'easting', 'northing']

# %%
# Categorical Columns

cat_data = df.select_dtypes(['object'])

cat_cols = cat_data.columns

print('categorical Columns : {}'.format(list(cat_cols)))
# Out:
# categorical Columns : ['name', 'address', 'postalcode', 'latitude', 'longitude', 'local_authority']

# %%
df.isnull().sum()
# Out:
# fsa_id             0
# name               0
# address            0
# postalcode         0
# easting            0
# northing           0
# latitude           0
# longitude          0
# local_authority    0
# dtype: int64

# %%
df.dtypes
# Out:
# fsa_id              int64
# name               object
# address            object
# postalcode         object
# easting             int64
# northing            int64
# latitude           object
# longitude          object
# local_authority    object
# dtype: object

# %%
df['latitude'] = df['latitude'].replace(['\\N'],np.NaN)
df['longitude'] = df['longitude'].replace(['\\N'],np.NaN)
df
# Out:
#        fsa_id                                      name  \
# 0          36                        Ark Bar Restaurant
# 1          74                                 Black Boy
# 2          75                               Black Horse
# 3          76                                Black Lion
# 4          97                              Brewers Arms
# ...       ...                                       ...
# 51325  597119  Wrexham & District War Memorial Club Ltd
# 51326  597127                 Wrexham Lager Social Club
# 51327  597130         Wrexham Rail Sports & Social Club
# 51328  597131                        Wrexham Rugby Club
# 51329  597137                                     Y Tai
#
#                                                  address postalcode  easting  \
# 0      Ark Bar And Restaurant, Cattawade Street, Bran...   CO11 1RH   610194
# 1      The Lady Elizabeth, 7 Market Hill, SUDBURY, Su...   CO10 2EA   587334
# ...

# %%
df2=df.dropna()
df2
# Out:
#        fsa_id                                      name  \
# 0          36                        Ark Bar Restaurant
# 1          74                                 Black Boy
# 4          97                              Brewers Arms
# 5         102                              Bristol Arms
# 6         122                           Caffeine Lounge
# ...       ...                                       ...
# 51325  597119  Wrexham & District War Memorial Club Ltd
# 51326  597127                 Wrexham Lager Social Club
# 51327  597130         Wrexham Rail Sports & Social Club
# 51328  597131                        Wrexham Rugby Club
# 51329  597137                                     Y Tai
#
#                                                  address postalcode  easting  \
# 0      Ark Bar And Restaurant, Cattawade Street, Bran...   CO11 1RH   610194
# 1      The Lady Elizabeth, 7 Market Hill, SUDBURY, Su...   CO10 2EA   587334
# ...

# %%
df2.to_csv('pub.csv',index=False)
